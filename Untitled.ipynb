# %%
from sklearn.metrics.pairwise import cosine_similarity
import torch
from torch import Tensor
import numpy as np
import tensorflow as tf
from sklearn.metrics.pairwise import cosine_similarity
from numpy import dot
from numpy.linalg import norm
import matplotlib.pyplot as plt

# %%
cs_tensor = torch.load('./cosine_similarity.pt')
cs_tensor = cs_tensor.detach().numpy()
plt.figure(1, figsize=(2^13, 2^13))
plt.imshow(cs_tensor, cmap='hot',aspect='auto',vmin=0, interpolation='nearest')
# plt.show()
plt.savefig('cs_hd.png', dpi=300)
plt.show()

# %%
cs_tensor = torch.load('./cosine_similarity.pt')
torch.reshape(cs_tensor, (6912, 3))
cs_tensor = cs_tensor.detach().numpy()
plt.figure(1, figsize=(2^13, 0.3))
plt.imshow(cs_tensor, cmap='hot',aspect='auto',vmin=0, interpolation='nearest')
# plt.show()
plt.savefig('cs_hd_reshaped.png', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [68], in <cell line: 2>()
#       1 cs_tensor = torch.load('./cosine_similarity.pt')
# ----> 2 torch.reshape(cs_tensor, (6912, 3))
#       3 cs_tensor = cs_tensor.detach().numpy()
#       4 plt.figure(1, figsize=(2^13, 0.3))
#
# RuntimeError: shape '[6912, 3]' is invalid for input of size 320256
